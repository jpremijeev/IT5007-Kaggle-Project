# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns 
import matplotlib.pyplot as plt

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ### Importing the data

# %%
data = pd.read_csv("train.csv") #/kaggle/input/us-college-completion-rate-analysis/
data
# Out:
#       Unnamed: 0  Completion_rate  Tuition_in_state  Tuition_out_state  \
# 0              0           0.6552           33560.0            33560.0
# 1              1           0.5246            7383.0            18543.0
# 2              2           0.4030           23144.0            23144.0
# 3              3           0.5472            6610.0            17770.0
# 4              4           0.8166           47004.0            47004.0
# ...          ...              ...               ...                ...
# 2359        2359           0.5311           24090.0            24090.0
# 2360        2360           0.5371           36660.0            36660.0
# 2361        2361           0.3677           30331.0            30331.0
# 2362        2362           0.5541            5055.0            16215.0
# 2363        2363           0.5871           33358.0            33358.0
#
#       Faculty_salary  Pell_grant_rate  SAT_average  ACT_50thPercentile  \
# 0             4285.0           0.2531       1029.0                21.0
# 1             9148.0           0.4752        963.0                21.0
# 2             7232.0           0.4668        984.0                21.0
# 3             9284.0           0.6369        877.0                18.0
# 4            11984.0           0.1337       1323.0                30.0
# ...              ...              ...          ...                 ...
# 2359          6705.0           0.3402        949.0                20.0
# 2360          6340.0           0.4075       1033.0                23.0
# 2361          6689.0           0.5791       1009.0                22.0
# 2362          9312.0           0.2151       1102.0                24.0
# 2363          8178.0           0.2640       1053.0                23.0
#
#       pct_White  pct_Black  pct_Hispanic  pct_Asian  Parents_middlesch  \
# 0        0.3771     0.0612        0.0590     0.1345           0.011561
# 1        0.2866     0.0331        0.4212     0.1011           0.107411
# 2        0.3085     0.1426        0.2309     0.0149           0.091241
# 3        0.1272     0.0572        0.6282     0.0557           0.163236
# 4        0.4251     0.0786        0.2268     0.0549           0.014868
# ...         ...        ...           ...        ...                ...
# 2359     0.6830     0.0544        0.0385     0.0225           0.019266
# 2360     0.6215     0.1582        0.0883     0.0257           0.028593
# 2361     0.5842     0.2277        0.0569     0.0221           0.029851
# 2362     0.7347     0.0113        0.0718     0.0117           0.017512
# 2363     0.5974     0.1482        0.0933     0.0304           0.011107
#
#       Parents_highsch  Parents_college
# 0            0.226397         0.762042
# 1            0.375165         0.517424
# 2            0.361314         0.547445
# 3            0.433621         0.403142
# 4            0.186091         0.799041
# ...               ...              ...
# 2359         0.439450         0.541284
# 2360         0.404816         0.566591
# 2361         0.370421         0.599729
# 2362         0.259759         0.722729
# 2363         0.249280         0.739613
#
# [2364 rows x 15 columns]

# %% [markdown]
# Checking data to ensure completeness

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2364 entries, 0 to 2363
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          2364 non-null   int64
#  1   Completion_rate     2364 non-null   float64
#  2   Tuition_in_state    2364 non-null   float64
#  3   Tuition_out_state   2364 non-null   float64
#  4   Faculty_salary      2364 non-null   float64
#  5   Pell_grant_rate     2364 non-null   float64
#  6   SAT_average         2364 non-null   float64
#  7   ACT_50thPercentile  2364 non-null   float64
#  8   pct_White           2364 non-null   float64
#  9   pct_Black           2364 non-null   float64
#  10  pct_Hispanic        2364 non-null   float64
#  11  pct_Asian           2364 non-null   float64
#  12  Parents_middlesch   2364 non-null   float64
#  13  Parents_highsch     2364 non-null   float64
#  14  Parents_college     2364 non-null   float64
# dtypes: float64(14), int64(1)
# memory usage: 277.2 KB

# %%
data.isna().sum()
# Out:
# Unnamed: 0            0
# Completion_rate       0
# Tuition_in_state      0
# Tuition_out_state     0
# Faculty_salary        0
# Pell_grant_rate       0
# SAT_average           0
# ACT_50thPercentile    0
# pct_White             0
# pct_Black             0
# pct_Hispanic          0
# pct_Asian             0
# Parents_middlesch     0
# Parents_highsch       0
# Parents_college       0
# dtype: int64

# %% [markdown]
# Check if the completion rate data follows a standard distribution or is weighted in any way.

# %%
sns.kdeplot(data['Completion_rate'])
plt.show()

# %% [markdown]
# **Inference** - the distribution of completion_rate feature is normal

# %% [markdown]
# # EDA and Data Preprocessing

# %%
data.describe().T
# Out:
#                      count          mean           std          min  \
# Unnamed: 0          2364.0   1181.500000    682.572340     0.000000
# Completion_rate     2364.0      0.539796      0.175897     0.038000
# Tuition_in_state    2364.0  19759.014382  12874.765104   480.000000
# Tuition_out_state   2364.0  25244.847716   9695.943019   480.000000
# Faculty_salary      2364.0   7974.087140   2259.787691  3186.000000
# Pell_grant_rate     2364.0      0.370193      0.142627     0.083300
# SAT_average         2364.0   1055.552876    133.310358   708.000000
# ACT_50thPercentile  2364.0     23.100254      3.437689    14.000000
# pct_White           2364.0      0.580825      0.219298     0.000000
# pct_Black           2364.0      0.146871      0.198238     0.000000
# pct_Hispanic        2364.0      0.106338      0.118509     0.000000
# pct_Asian           2364.0      0.046064      0.062720     0.000000
# Parents_middlesch   2364.0      0.028537      0.021679     0.002952
# Parents_highsch     2364.0      0.303929      0.080973     0.075059
# Parents_college     2364.0      0.667534      0.092202     0.384661
#
#                              25%           50%           75%           max
# Unnamed: 0            590.750000   1181.500000   1772.250000   2363.000000
# Completion_rate         0.414575      0.528650      0.657000      0.977900
# Tuition_in_state     8113.750000  15022.000000  29192.500000  55056.000000
# Tuition_out_state   17791.750000  23803.000000  30818.750000  55056.000000
# Faculty_salary       6416.500000   7528.500000   9082.750000  22146.000000
# Pell_grant_rate         0.271675      0.357600      0.446925      0.996300
# SAT_average           972.000000   1037.000000   1115.250000   1519.000000
# ACT_50thPercentile     21.000000     23.000000     25.000000     34.000000
# pct_White               0.477575      0.629800      0.743750      0.962000
# pct_Black               0.045000      0.076800      0.157225      1.000000
# pct_Hispanic            0.035900      0.066900      0.127100      0.948700
# pct_Asian               0.010575      0.021750      0.054400      0.437100
# Parents_middlesch       0.015270      0.022839      0.034750      0.201153
# Parents_highsch         0.251640      0.314879      0.364107      0.508948
# Parents_college         0.602832      0.658168      0.729016      0.915559

# %% [markdown]
# As the most of the data are already in percentages, there is not much use in normalisation and standardisation of the data, as they are already in a sense normalised and standardised. The ones with magnitude are also in similar magnitude, e.g. the tuition fee and salary are in the same dollar value.

# %% [markdown]
# Plot a scatterplot of each feature's relationship to completion rate. Identified that features such as tuition fees, faculty salary, Pell grant rate,	SAT scores, and parents' education levels have a somewhat linear relationship to completion rate.

# %%
feature_names = data.columns[2:]

# %%
features = ['Tuition_in_state', 'Tuition_out_state', 'Faculty_salary', 'Pell_grant_rate', 'SAT_average', 'ACT_50thPercentile', 'pct_White', 'pct_Black', 'pct_Hispanic', 
            'pct_Asian', 'Parents_middlesch', 'Parents_highsch', 'Parents_college']
target = 'Completion_rate'

corrs = data[features + [target]].corr()[target][:-1]

# Create binary variable indicating highly correlated features
high_corr = pd.Series(np.where(corrs.abs() > 0.5, 'High Correlation', 'Low Correlation'))

# Create scatter plot matrix with color-coded highly correlated features
sns.pairplot(data, x_vars=features, y_vars=target, hue=high_corr, palette='Oranges_r', height=5)

# Add legend to the plot
handles = [plt.plot([],[], marker="o", ls="", color=color)[0] for color in ['orange', 'blue']]
labels = ['High Correlation', 'Low Correlation']
plt.legend(handles, labels, loc='center left', bbox_to_anchor=(1, 0.5))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-efb5eb4e206e> in <cell line: 11>()
#       9
#      10 # Create scatter plot matrix with color-coded highly correlated features
# ---> 11 sns.pairplot(data, x_vars=features, y_vars=target, hue=high_corr, palette='Oranges_r', height=5)
#      12
#      13 # Add legend to the plot
#
# /usr/local/lib/python3.9/dist-packages/seaborn/axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2112     # Set up the PairGrid
#    2113     grid_kws.setdefault("diag_sharey", diag_kind == "hist")
# -> 2114     grid = PairGrid(data, vars=vars, x_vars=x_vars, y_vars=y_vars, hue=hue,
#    2115                     hue_order=hue_order, palette=palette, corner=corner,
#    2116                     height=height, aspect=aspect, dropna=dropna, **grid_kws)
#
# /usr/local/lib/python3.9/dist-packages/seaborn/axisgrid.py in __init__(self, data, hue, vars, x_vars, y_vars, hue_order, palette, hue_kws, corner, diag_sharey, height, aspect, layout_pad, despine, dropna)
#    1244         # Sort out the variables that define the grid
#    1245         numeric_cols = self._find_numeric_cols(data)
# -> 1246         if hue in numeric_cols:
#    1247             numeric_cols.remove(hue)
#    1248         if vars is not None:
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/generic.py in __nonzero__(self)
#    1525     @final
#    1526     def __nonzero__(self):
# -> 1527         raise ValueError(
#    1528             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
import seaborn as sns
sns.pairplot(data, x_vars=['Tuition_in_state', 'Tuition_out_state',	'Faculty_salary',	'Pell_grant_rate',	'SAT_average',	'ACT_50thPercentile',	'pct_White',	'pct_Black',	
                           'pct_Hispanic',	'pct_Asian',	'Parents_middlesch',	'Parents_highsch',	'Parents_college'], y_vars='Completion_rate', height=5)

# %% [markdown]
# Check for correlation of features

# %%
features = data.drop(['Unnamed: 0', 'Completion_rate'], axis = 1)
features.corr().style.background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_59265_row0_col0, #T_59265_row1_col1, #T_59265_row2_col2, #T_59265_row3_col3, #T_59265_row4_col4, #T_59265_row5_col5, #T_59265_row6_col6, #T_59265_row7_col7, #T_59265_row8_col8, #T_59265_row9_col9, #T_59265_row10_col10, #T_59265_row11_col11, #T_59265_row12_col12 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_59265_row0_col1 {
#   background-color: #08478d;
#   color: #f1f1f1;
# }
# #T_59265_row0_col2 {
#   background-color: #5ba3d0;
#   color: #f1f1f1;
# }
# #T_59265_row0_col3 {
#   background-color: #cee0f2;
#   color: #000000;
# }
# #T_59265_row0_col4 {
#   background-color: #3383be;
#   color: #f1f1f1;
# }
# #T_59265_row0_col5 {
#   background-color: #3181bd;
#   color: #f1f1f1;
# }
# #T_59265_row0_col6, #T_59265_row1_col6 {
#   background-color: #9ac8e0;
#   color: #000000;
# }
# #T_59265_row0_col7 {
#   background-color: #bfd8ed;
#   color: #000000;
# }
# #T_59265_row0_col8 {
#   background-color: #add0e6;
#   color: #000000;
# }
# #T_59265_row0_col9 {
#   background-color: #84bcdb;
#   color: #000000;
# }
# #T_59265_row0_col10, #T_59265_row10_col1 {
#   background-color: #b3d3e8;
#   color: #000000;
# }
# #T_59265_row0_col11 {
#   background-color: #bdd7ec;
#   color: #000000;
# }
# #T_59265_row0_col12, #T_59265_row9_col5, #T_59265_row12_col1 {
#   background-color: #2f7fbc;
#   color: #f1f1f1;
# }
# #T
{
#   background-color: #9cc9e1;
#   color: #000000;
# }
# #T_59265_row10_col9 {

# %%
plt.figure(figsize=(15,7))
sns.heatmap(features.corr()[np.abs(features.corr()) < 0.6],annot=True,annot_kws={'size':15},cmap="YlGnBu")
plt.show()

# %% [markdown]
# **Inference** - Filter out features with high correlation to each other.
# Hence we will drop tuition_out_state and drop Parents_college. Choose one between pct_white and pct_black and choose one between SAT_average and ACT_median.

# %%
features = features.drop(['Tuition_out_state', 'ACT_50thPercentile', 'pct_Black', 'Parents_college'], axis = 1)
features.head()
# Out:
#    Tuition_in_state  Faculty_salary  Pell_grant_rate  SAT_average  pct_White  \
# 0           33560.0          4285.0           0.2531       1029.0     0.3771
# 1            7383.0          9148.0           0.4752        963.0     0.2866
# 2           23144.0          7232.0           0.4668        984.0     0.3085
# 3            6610.0          9284.0           0.6369        877.0     0.1272
# 4           47004.0         11984.0           0.1337       1323.0     0.4251
#
#    pct_Hispanic  pct_Asian  Parents_middlesch  Parents_highsch
# 0        0.0590     0.1345           0.011561         0.226397
# 1        0.4212     0.1011           0.107411         0.375165
# 2        0.2309     0.0149           0.091241         0.361314
# 3        0.6282     0.0557           0.163236         0.433621
# 4        0.2268     0.0549           0.014868         0.186091

# %% [markdown]
# Use Lasso regression to check for significance of features.

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import Lasso
y = data['Completion_rate']
X = features
pipeline = Pipeline([('scaler',StandardScaler()),('model',Lasso())])
search = GridSearchCV(pipeline,{'model__alpha':np.arange(0.1,10,0.1)},cv = 5, scoring="neg_mean_squared_error",verbose=3)
search.fit(X, y)
search.best_params_
# Out:
# Fitting 5 folds for each of 99 candidates, totalling 495 fits
# [CV 1/5] END .................model__alpha=0.1;, score=-0.019 total time=   0.0s
# [CV 2/5] END .................model__alpha=0.1;, score=-0.021 total time=   0.0s
# [CV 3/5] END .................model__alpha=0.1;, score=-0.021 total time=   0.0s
# [CV 4/5] END .................model__alpha=0.1;, score=-0.017 total time=   0.0s
# [CV 5/5] END .................model__alpha=0.1;, score=-0.020 total time=   0.0s
# [CV 1/5] END .................model__alpha=0.2;, score=-0.029 total time=   0.0s
# [CV 2/5] END .................model__alpha=0.2;, score=-0.033 total time=   0.0s
# [CV 3/5] END .................model__alpha=0.2;, score=-0.034 total time=   0.0s
# [CV 4/5] END .................model__alpha=0.2;, score=-0.028 total time=   0.0s
# [CV 5/5] END .................model__alpha=0.2;, score=-0.031 total time=   0.0s
# [CV 1/5] END .model__alpha=0.30000000000000004;, score=-0.029 total time=   0.0s
# [CV 2/5] END .model__alpha=0.30000000000000004;, score=-0.033 total time=   0.0s
# [CV 3/5] END .model__alpha=0.30000000000000004;, score=-0.034 total time=   0.0s
# [CV 4/5] END .model__alpha=0.30000000000000004;, score=-0.028 total time=   0.0s
# [CV 5/5] END .model__alpha=0.30000000000000004;, score=-0.031 total time=   0.0s
# [CV 1/5] END .................model__alpha=0.4;, score=-0.029 total time=   0.0s
# [CV 2/5] END .................model__alpha=0.4;, score=-0.033 total time=   0.0s
# [CV 3/5] END .................model__alpha=0.4;, score=-0.034 total time=   0.0s
# [CV 4/5] END .................model__alpha=0.4;, score=-0.028 total time=   0.0s
# [CV 5/5] END .................model__alpha=0.4;, score=-0.031 total time=   0.0s
# [CV 1/5] END .................model__alpha=0.5;, score=-0.029 total time=   0.0s
# [CV 2/5] END .................model__alpha=0.5;, score=-0.033 total time=   0.0s
# [CV 3/5] END .................model__alpha=0.5;, score=-0.034 total time=   0.0s
# [CV 4/5] END .................model__alpha=0.5;, score=-0.028 total time=   0.0s
# [CV 5/5] END .................model__alpha=0.5;, score=-0.031 total time=   0.0s
# [CV 1/5] END .................model__alpha=0.6;, score=-0.029 total time=   0.0s
# [CV 2/5] END .................model__alpha=0.6;, score=-0.033 total time=   0.0s
# [CV 3/5] END .................model__alpha=0.6;, score=-0.034 total time=   0.0s
# [CV 4/5] END .................model__alpha=0.6;, score=-0.028 total time=   0.0s
# [CV 5/5] END .................model__alpha=0.6;, score=-0.031 total time=   0.0s
# [CV 1/5] END ..model__alpha=0.7000000000000001;, score=-0.029 total time=   0.0s
# [CV 2/5] END ..model__alpha=0.7000000000000001;, score=-0.033 total time=   0.0s
# [CV 3/5] END ..model__alpha=0.7000000000000001;, score=-0.034 total time=   0.0s
# [CV 4/5] END ..model__alpha=0.7000000000000001;, score=-0.028 total time=   0.0s
# [CV 5/5] END ..model__alpha=0.7000000000000001;, score=-0.031 total time=   0.0s
# [CV 1/5] END .................model__alpha=0.8;, score=-0.029 total time=   0.0s
# [CV 2/5] END .................model__alpha=0.8;, score=-0.033 total time=   0.0s
# [CV 3/5] END .................model__alpha=0.8;, score=-0.034 total time=   0.0s
# [CV 4/5] END .................model__alpha=0.8;, score=-0.028 total time=   0.0s
# [CV 5/5] END .................model__alpha=0.8;, score=-0.031 total time=   0.0s
# [CV 1/5] END .................model__alpha=0.9;, score=-0.029 total time=   0.0s
# [CV 2/5] END .................model__alpha=0.9;, score=-0.033 total time=   0.0s
# [CV 3/5] END .................model__alpha=0.9;, score=-0.034 total time=   0.0s
# [CV 4/5] END .................model__alpha=0.9;, score=-0.028 total time=   0.0s
# [CV 5/5] END .................model__alpha=0.9;, score=-0.031 total time=   0.0s
# [CV 1/5] END .................model__alpha=1.0;, score=-0.029 total time=   0.0s
# [CV 2/5] END .................model__alpha=1.0;, score=-0.033 total time=   0.0s
# [CV 3/5] END .................model__alpha=1.0;, score=-0.034 total time=   0.0s
# [CV 4/5] END .................model__alpha=1.0;, score=-0.028 total time=   0.0s
# [CV 5/5] END .................model__alpha=1.0;, score=-0.031 total time=   0.0s
# [CV 1/5] END .................model__alpha=1.1;, score=-0.029 total time=   0.0s
# [CV 2/5] END .................model__alpha=1.1;, score=-0.033 total time=   0.0s
# [CV 3/5] END .................model__alpha=1.1;, score=-0.034 total time=   0.0s
# [CV 4/5] END .................model__alpha=1.1;, score=-0.028 total time=   0.0s
# [CV 5/5] END .................model__alpha=1.1;, score=-0.031 total time=   0.0s
# [CV 1/5] END ..model__alpha=1.2000000000000002;, score=-0.029 total time=   0.0s
# [CV 2/5] END ..model__alpha=1.2000000000000002;, score=-0.033 total time=   0.0s
# [CV 3/5] END ..model__alpha=1.2000000000000002;, score=-0.034 total time=   0.0s
# [CV 4/5] END ..model__alpha=1.2000000000000002;, score=-0.028 total time=   0.0s
# [CV 5/5] END ..model__alpha=1.2000000000000002;, score=-0.031 total time=   0.0s
# [CV 1/5] END ..model__alpha=1.3000000000000003;, score=-0.029 total time=   0.0s
# [CV 2/5] END ..model__alpha=1.3000000000000003;, score=-0.033 total time=   0.0s
# [CV 3/5] END ..model__alpha
, score=-0.033 total time=   0.0s
# [CV 3/5] END .................model__alpha=9.4;, score=-0.034 total time=   0.0s
# [CV 4/5] END .................model__alpha=9.4;, score=-0.028 total time=   0.0s
# [CV 5/5] END .................model__alpha=9.4;, score=-0.031 total time=   0.0s
# [CV 1/5] END .................model__alpha=9.5;, score=-0.029 total time=   0.0s
# [CV 2/5] END .................model__alpha=9.5;, score=-0.033 total time=   0.0s
# [CV 3/5] END .................model__alpha=9.5;, score=-0.034 total time=   0.0s
# [CV 4/5] END .................model__alpha=9.5;, score=-0.028 total time=   0.0s
# [CV 5/5] END .................model__alpha=9.5;, score=-0.031 total time=   0.0s
# [CV 1/5] END .................model__alpha=9.6;, score=-0.029 total time=   0.0s
# [CV 2/5] END .................model__alpha=9.6;, score=-0.033 total time=   0.0s
# [CV 3/5] END .................model__alpha=9.6;, score=-0.034 total time=   0.0s
# [CV 4/5] END .................model__alpha=9.6;, score=-0.028 total time=   0.0s
# [CV 5/5] END .................model__alpha=9.6;, score=-0.031 total time=   0.0s
# [CV 1/5] END ...model__alpha=9.700000000000001;, score=-0.029 total time=   0.0s
# [CV 2/5] END ...model__alpha=9.700000000000001;, score=-0.033 total time=   0.0s
# [CV 3/5] END ...model__alpha=9.700000000000001;, score=-0.034 total time=   0.0s
# [CV 4/5] END ...model__alpha=9.700000000000001;, score=-0.028 total time=   0.0s
# [CV 5/5] END ...model__alpha=9.700000000000001;, score=-0.031 total time=   0.0s
# [CV 1/5] END .................model__alpha=9.8;, score=-0.029 total time=   0.0s
# [CV 2/5] END .................model__alpha=9.8;, score=-0.033 total time=   0.0s
# [CV 3/5] END .................model__alpha=9.8;, score=-0.034 total time=   0.0s
# [CV 4/5] END .................model__alpha=9.8;, score=-0.028 total time=   0.0s
# [CV 5/5] END .................model__alpha=9.8;, score=-0.031 total time=   0.0s
# [CV 1/5] END .................model__alpha=9.9;, score=-0.029 total time=   0.0s
# [CV 2/5] END .................model__alpha=9.9;, score=-0.033 total time=   0.0s
# [CV 3/5] END .................model__alpha=9.9;, score=-0.034 total time=   0.0s
# [CV 4/5] END .................model__alpha=9.9;, score=-0.028 total time=   0.0s
# [CV 5/5] END .................model__alpha=9.9;, score=-0.031 total time=   0.0s
# {'model__alpha': 0.1}

# %%
pipeline = Pipeline([('scaler',StandardScaler()),('model',Lasso(alpha = 0.1))])
names = features.columns
lasso_coef = pipeline.fit(X, y).named_steps['model'].coef_
plt.bar(names, lasso_coef)
plt.xticks(rotation=45)
plt.show()
for name, coef in zip(names, lasso_coef):
  print(f'{name}: {coef:.4f}')
# Out:
# Tuition_in_state: 0.0000
# Faculty_salary: 0.0000
# Pell_grant_rate: -0.0000
# SAT_average: 0.0463
# pct_White: 0.0000
# pct_Hispanic: 0.0000
# pct_Asian: 0.0000
# Parents_middlesch: -0.0000
# Parents_highsch: -0.0000

# %% [markdown]
# **Inference** - From the Lasso regression analysis, it appears that only SAT_average is a significant feature. However, if we build our model using only SAT, the R-squared score is low (0.693), suggesting that the model may be underfitted. Therefore, we will try to build our model with a few features.

# %%
import statsmodels.formula.api as smf
features_selected = ['SAT_average']
model = smf.ols(formula='Completion_rate ~ SAT_average', data=data).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        Completion_rate   R-squared:                       0.693
# Model:                            OLS   Adj. R-squared:                  0.692
# Method:                 Least Squares   F-statistic:                     5320.
# Date:                Mon, 03 Apr 2023   Prob (F-statistic):               0.00
# Time:                        07:44:03   Log-Likelihood:                 2148.4
# No. Observations:                2364   AIC:                            -4293.
# Df Residuals:                    2362   BIC:                            -4281.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept      -0.6192      0.016    -38.660      0.000      -0.651      -0.588
# SAT_average     0.0011   1.51e-05     72.935      0.000       0.001       0.001
# ==============================================================================
# Omnibus:                       15.878   Durbin-Watson:                   1.985
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               16.253
# Skew:                          -0.181   Prob(JB):                     0.000296
# Kurtosis:                       3.185   Cond. No.                     8.49e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.49e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# Explore PCA

# %%
from sklearn.decomposition import PCA

PCA_pipe = Pipeline([('scaler', StandardScaler()), ('pca', PCA())])
PCA_pipe.fit(features, data['Completion_rate'])

plt.plot(PCA_pipe['pca'].explained_variance_ratio_)
print(PCA_pipe['pca'].explained_variance_ratio_.cumsum())

PCA_pipe = Pipeline([('scaler', StandardScaler()), ('pca', PCA(n_components = 3))])
PCA_pipe.fit(features, data['Completion_rate'])
vectors = PCA_pipe['pca'].components_.round(4)
print(vectors)
# Out:
# [0.40780739 0.68358861 0.77423379 0.85925055 0.91138148 0.94333724
#  0.96793051 0.98511658 1.        ]
# [[ 0.2863  0.3861 -0.4455  0.4801  0.1786 -0.0819  0.2379 -0.2131 -0.4465]
#  [ 0.1032  0.2811  0.0925  0.0734 -0.4533  0.5005  0.4422  0.4943  0.0225]
#  [ 0.6015 -0.0704  0.3481 -0.1108 -0.5272 -0.3411  0.0316 -0.2947 -0.1326]]

# %%
vectors = pd.DataFrame(vectors, columns = features.columns)
print(vectors)
# Out:
#    Tuition_in_state  Faculty_salary  Pell_grant_rate  SAT_average  pct_White  \
# 0            0.2863          0.3861          -0.4455       0.4801     0.1786
# 1            0.1032          0.2811           0.0925       0.0734    -0.4533
# 2            0.6015         -0.0704           0.3481      -0.1108    -0.5272
#
#    pct_Hispanic  pct_Asian  Parents_middlesch  Parents_highsch
# 0       -0.0819     0.2379            -0.2131          -0.4465
# 1        0.5005     0.4422             0.4943           0.0225
# 2       -0.3411     0.0316            -0.2947          -0.1326

# %% [markdown]
# ### Creating a simple regression model

# %% [markdown]
# Create a baseline regression model using OLS. Remove features with high P-values as model is not accurate.

# %%
features_selected = ['Tuition_in_state', 'Faculty_salary', 'Pell_grant_rate', 'SAT_average', 'pct_White', 'pct_Hispanic', 'pct_Asian', 'Parents_middlesch', 'Parents_highsch']
model = smf.ols(formula='Completion_rate ~ ' + ' + '.join(features_selected), data=data).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        Completion_rate   R-squared:                       0.769
# Model:                            OLS   Adj. R-squared:                  0.768
# Method:                 Least Squares   F-statistic:                     868.5
# Date:                Mon, 03 Apr 2023   Prob (F-statistic):               0.00
# Time:                        07:44:04   Log-Likelihood:                 2484.1
# No. Observations:                2364   AIC:                            -4948.
# Df Residuals:                    2354   BIC:                            -4890.
# Df Model:                           9
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept            -0.0267      0.037     -0.732      0.464      -0.098       0.045
# Tuition_in_state   2.203e-06   1.59e-07     13.856      0.000    1.89e-06    2.51e-06
# Faculty_salary     1.331e-05   1.35e-06      9.853      0.000    1.07e-05     1.6e-05
# Pell_grant_rate      -0.0360      0.024     -1.527      0.127      -0.082       0.010
# SAT_average           0.0005   2.84e-05     16.688      0.000       0.000       0.001
# pct_White             0.1054      0.013      7.939      0.000       0.079       0.131
# pct_Hispanic          0.0616      0.024      2.586      0.010       0.015       0.108
# pct_Asian             0.3041      0.043      7.030      0.000       0.219       0.389
# Parents_middlesch     0.1808      0.151      1.198      0.231      -0.115       0.477
# Parents_highsch      -0.5168      0.038    -13.745      0.000      -0.591      -0.443
# ==============================================================================
# Omnibus:                       10.036   Durbin-Watson:                   2.015
# Prob(Omnibus):                  0.007   Jarque-Bera (JB):               12.941
# Skew:                          -0.027   Prob(JB):                      0.00155
# Kurtosis:                       3.358   Cond. No.                     2.17e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.17e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
features_selected = ['Tuition_in_state', 'Faculty_salary', 'SAT_average', 'pct_White', 'pct_Hispanic', 'pct_Asian', 'Parents_highsch']
model2 = smf.ols(formula='Completion_rate ~ ' + ' + '.join(features_selected), data=data).fit()
print(model2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        Completion_rate   R-squared:                       0.768
# Model:                            OLS   Adj. R-squared:                  0.768
# Method:                 Least Squares   F-statistic:                     1116.
# Date:                Mon, 03 Apr 2023   Prob (F-statistic):               0.00
# Time:                        07:44:04   Log-Likelihood:                 2482.4
# No. Observations:                2364   AIC:                            -4949.
# Df Residuals:                    2356   BIC:                            -4903.
# Df Model:                           7
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept           -0.0601      0.030     -1.973      0.049      -0.120      -0.000
# Tuition_in_state  2.237e-06   1.56e-07     14.299      0.000    1.93e-06    2.54e-06
# Faculty_salary    1.344e-05   1.31e-06     10.248      0.000    1.09e-05     1.6e-05
# SAT_average          0.0005   2.76e-05     17.588      0.000       0.000       0.001
# pct_White            0.1155      0.011     10.732      0.000       0.094       0.137
# pct_Hispanic         0.0856      0.017      5.075      0.000       0.053       0.119
# pct_Asian            0.3277      0.040      8.151      0.000       0.249       0.407
# Parents_highsch     -0.5124      0.033    -15.333      0.000      -0.578      -0.447
# ==============================================================================
# Omnibus:                       10.469   Durbin-Watson:                   2.016
# Prob(Omnibus):                  0.005   Jarque-Bera (JB):               13.729
# Skew:                          -0.016   Prob(JB):                      0.00104
# Kurtosis:                       3.372   Cond. No.                     6.55e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.55e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# Check for normality and heteroscedasticity by plotting residual values. There is non-linearity and heteroscedasticity.

# %%
y = data['Completion_rate']
X = data[features_selected]
pred_y = model2.predict(X) 
residuals = pred_y - y
plt.figure(figsize=(8,5))
sns.residplot(x = pred_y, y = residuals, lowess=True)
# Out:
# <Axes: >

# %% [markdown]
# Build polynomial model and remove variables with high P-values.

# %%
poly_features = []
for feature in features_selected:
  poly_features.append(feature)
  poly_features.append(f'I({feature}**2)')
poly_model = smf.ols(formula='Completion_rate ~ ' + ' + '.join(poly_features), data=data).fit()
print(poly_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        Completion_rate   R-squared:                       0.789
# Model:                            OLS   Adj. R-squared:                  0.788
# Method:                 Least Squares   F-statistic:                     629.1
# Date:                Mon, 03 Apr 2023   Prob (F-statistic):               0.00
# Time:                        07:44:05   Log-Likelihood:                 2596.0
# No. Observations:                2364   AIC:                            -5162.
# Df Residuals:                    2349   BIC:                            -5076.
# Df Model:                          14
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                   -0.2264      0.105     -2.158      0.031      -0.432      -0.021
# Tuition_in_state          9.734e-06   6.54e-07     14.878      0.000    8.45e-06     1.1e-05
# I(Tuition_in_state ** 2) -1.583e-10   1.43e-11    -11.055      0.000   -1.86e-10    -1.3e-10
# Faculty_salary            4.341e-05   4.44e-06      9.787      0.000    3.47e-05    5.21e-05
# I(Faculty_salary ** 2)   -1.475e-09    2.4e-10     -6.153      0.000   -1.94e-09      -1e-09
# SAT_average                  0.0004      0.000      1.823      0.068   -3.04e-05       0.001
# I(SAT_average ** 2)       9.655e-08   1.01e-07      0.953      0.341   -1.02e-07    2.95e-07
# pct_White                   -0.1673      0.038     -4.404      0.000      -0.242      -0.093
# I(pct_White ** 2)            0.2786      0.038      7.260      0.000       0.203       0.354
# pct_Hispanic                 0.1420      0.043      3.267      0.001       0.057       0.227
# I(pct_Hispanic ** 2)        -0.0962      0.066     -1.463      0.143      -0.225       0.033
# pct_Asian                    0.4125      0.099      4.168      0.000       0.218       0.607
# I(pct_Asian ** 2)           -0.3115      0.288     -1.082      0.279      -0.876       0.253
# Parents_highsch             -0.6337      0.164     -3.869      0.000      -0.955      -0.312
# I(Parents_highsch ** 2)      0.3746      0.260      1.440      0.150      -0.135       0.885
# ==============================================================================
# Omnibus:                       26.930   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               45.141
# Skew:                          -0.009   Prob(JB):                     1.58e-10
# Kurtosis:                       3.677   Cond. No.                     1.59e+11
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.59e+11. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
poly_features = []
for feature in features_selected:
  poly_features.append(feature)
  if feature in ['Tuition_in_state', 'Faculty_salary', 'pct_White']:
    poly_features.append(f'I({feature}**2)')
poly_model2 = smf.ols(formula='Completion_rate ~ ' + ' + '.join(poly_features), data=data).fit()
print(poly_model2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        Completion_rate   R-squared:                       0.789
# Model:                            OLS   Adj. R-squared:                  0.788
# Method:                 Least Squares   F-statistic:                     878.3
# Date:                Mon, 03 Apr 2023   Prob (F-statistic):               0.00
# Time:                        07:44:06   Log-Likelihood:                 2591.8
# No. Observations:                2364   AIC:                            -5162.
# Df Residuals:                    2353   BIC:                            -5098.
# Df Model:                          10
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                   -0.3610      0.039     -9.363      0.000      -0.437      -0.285
# Tuition_in_state          9.314e-06   6.22e-07     14.968      0.000    8.09e-06    1.05e-05
# I(Tuition_in_state ** 2) -1.467e-10   1.34e-11    -10.981      0.000   -1.73e-10    -1.2e-10
# Faculty_salary            4.195e-05   3.94e-06     10.649      0.000    3.42e-05    4.97e-05
# I(Faculty_salary ** 2)   -1.369e-09   2.04e-10     -6.698      0.000   -1.77e-09   -9.68e-10
# SAT_average                  0.0006   2.78e-05     22.149      0.000       0.001       0.001
# pct_White                   -0.1531      0.032     -4.801      0.000      -0.216      -0.091
# I(pct_White ** 2)            0.2558      0.033      7.733      0.000       0.191       0.321
# pct_Hispanic                 0.0824      0.017      4.906      0.000       0.049       0.115
# pct_Asian                    0.3174      0.039      8.124      0.000       0.241       0.394
# Parents_highsch             -0.4128      0.034    -12.288      0.000      -0.479      -0.347
# ==============================================================================
# Omnibus:                       27.059   Durbin-Watson:                   2.003
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               45.464
# Skew:                          -0.003   Prob(JB):                     1.34e-10
# Kurtosis:                       3.679   Cond. No.                     2.59e+10
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.59e+10. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# By increasing the order of the features, the R-squared score has improved. Model is now more linear, although still with some heteroscedasticity

# %%
pred_y = poly_model2.predict(X) 
residuals = pred_y - y
plt.figure(figsize=(8,5))
sns.residplot(x = pred_y, y = residuals, lowess=True)
# Out:
# <Axes: >

# %% [markdown]
# Using cross validation, the R-score has also good range of 0.74 to 0.8

# %%
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression
poly_X = X.copy()
poly_X['Tuition_in_state ** 2'] = X['Tuition_in_state'] ** 2
poly_X['Faculty_salary ** 2'] = X['Faculty_salary'] ** 2
poly_X['pct_White ** 2'] = X['pct_White'] ** 2
OLS_score = cross_val_score(LinearRegression(), poly_X, y, cv = 5)
print(f'CV score with 5 folds {OLS_score}')
# Out:
# CV score with 5 folds [0.74502097 0.78341023 0.80078569 0.80317979 0.79601149]

# %% [markdown]
# It seems that there are no strong predictors in our list of features based on the value of the coefficient and also the outcome of the LASSO regression (if there was a only a few strong predictors, LASSO would have pointed them out, instead, only one strong predictor was identified). When there are a number of weak features, boosting is one recommended solution, hence we tried xgboost as a model.

# %%
import xgboost as xgb
X = data[features_selected]
y = data['Completion_rate']
model_xgb = xgb.XGBRegressor(seed = 42)
xgb_score = cross_val_score(model_xgb, X, y, cv = 5)
print(f'CV score with 5 folds {xgb_score}')
# Out:
# CV score with 5 folds [0.78574826 0.84314459 0.84003148 0.8507078  0.82030266]

# %% [markdown]
# Initial scoring using CV provided a higher R-score of between 0.78 to 0.85. We then do a gridsearch to tune the hyperparameters

# %%
from sklearn.model_selection import GridSearchCV
# learning rate
eta = [0.1]
# max_depth of the tree
max_depth = [8, 9, 10, 11, 12]
#min_child_weight
min_child_weight = [3, 4, 5]
#for L1 regularization
alpha = [0.01, 0.1, 10]
#subsampling to reduce overfitting
subsample = [0.2, 0.5, 0.7]
# Create the random grid
search_grid = {'eta': eta,
               'max_depth': max_depth,
               'min_child_weight': min_child_weight,
               'alpha': alpha,
               'subsample': subsample,
               'seed' : [42]}

tuning_model = xgb.XGBRegressor()
clf = GridSearchCV(tuning_model, search_grid, cv = 5)
clf.fit(X, y)
print(clf.best_params_)
# Out:
# {'alpha': 0.1, 'eta': 0.1, 'max_depth': 11, 'min_child_weight': 3, 'seed': 42, 'subsample': 0.5}
# 0.8496864155109334

# %%
model_xgb_final = xgb.XGBRegressor(alpha = 0.1, eta = 0.1, max_depth =  11, min_child_weight = 3, seed = 42, subsample = 0.5)
xgb_score_final = cross_val_score(model_xgb_final, X, y, cv = 5)
print(f'CV score with 5 folds {xgb_score_final}')
# Out:
# CV score with 5 folds [0.81530052 0.85605415 0.86756514 0.86050223 0.84901004]

# %%
model_xgb_final.fit(X, y)
pred_y = model_xgb_final.predict(X)
residuals = pred_y - y
plt.figure(figsize=(10,7))
sns.residplot(x = pred_y, y = residuals, lowess=True)
# Out:
# <Axes: ylabel='Completion_rate'>

# %% [markdown]
# Wthe 5 fold CV score, we see that the score does not deviate too much, hence there shouldn't be overfitting. Based on the plot of variance to predicted value, there is also no heteroscadacity

# %% [markdown]
# ### Creating our submission

# %%
test = pd.read_csv("x_test.csv") #/kaggle/input/us-college-completion-rate-analysis/
x_pred = test[features_selected]
y_pred = poly_model2.predict(x_pred)
print(y_pred.describe())
# Out:
# count    1165.000000
# mean        0.538283
# std         0.155248
# min         0.104568
# 25%         0.435016
# 50%         0.523759
# 75%         0.623220
# max         0.996654
# dtype: float64

# %%
submission = pd.DataFrame.from_dict({'Completion_rate': y_pred})
submission
# Out:
#       Completion_rate
# 0            0.439902
# 1            0.471283
# 2            0.457351
# 3            0.432281
# 4            0.417905
# ...               ...
# 1160         0.510867
# 1161         0.492273
# 1162         0.556372
# 1163         0.507581
# 1164         0.645434
#
# [1165 rows x 1 columns]

# %%
submission.to_csv('submission.csv', index = True, index_label = "id")

# %% [markdown]
# ### To submit your submission
#
# On the panel on your right, select the drop down "Submit to competition", and submit this notebook. Ensure that your submission is named ```submission.csv```!
